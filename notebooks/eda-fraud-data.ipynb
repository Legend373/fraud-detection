# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.fraud_data_pipeline import FraudDataPipeline
from scripts.fraude_eda_pipeline import FraudEDAPipeline

df = FraudDataPipeline(
    "../data/raw/Fraud_Data.csv",
    "../data/raw/IpAddress_to_Country.csv"
).run()

eda = FraudEDAPipeline(df).run()

eda["class_ratio"]
eda["fraud_by_country"]
# Out:
# d:\week-5\fraud-detection\src\utils\data_cleaning.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   self.df[col].fillna(self.df[col].median(), inplace=True)
# d:\week-5\fraud-detection\src\utils\data_cleaning.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
eda["class_counts"]
# Out:
# class
# 0    136961
# 1     14151
# Name: count, dtype: int64

# %%
eda["univariate"]
# Out:
#                        purchase_time        user_id  \
# count                         151112  151112.000000
# mean   2015-06-16 02:56:38.759952640  200171.040970
# min              2015-01-01 00:00:44       2.000000
# 25%       2015-04-18 14:41:25.500000  100642.500000
# 50%       2015-06-18 13:46:17.500000  199958.000000
# 75%       2015-08-17 18:48:31.500000  300054.000000
# max              2015-12-16 02:56:05  400000.000000
# std                              NaN  115369.285024
#
#                          signup_time  purchase_value            age  \
# count                         151112   151112.000000  151112.000000
# mean   2015-04-20 00:56:09.511329024       36.935372      33.140704
# min              2015-01-01 00:00:42        9.000000      18.000000
# 25%       2015-02-18 09:52:48.500000       22.000000      27.000000
# 50%              2015-04-19 04:41:30       35.000000      33.000000
# 75%    2015-06-18 14:47:22.750000128       49.000000      39.000000
# ...

# %%
eda["bivariate"]
# Out:
#              user_id  purchase_value        age    ip_address  ip_int  \
# class
# 0      200098.920123       36.929418  33.122356  2.154235e+09     NaN
# 1      200869.065366       36.993004  33.318281  2.131918e+09     NaN
#
#        hour_of_day  day_of_week  time_since_signup  txn_count_1h
# class
# 0        11.517249     2.999606       5.191179e+06           1.0
# 1        11.563635     3.130026       2.423842e+06           1.0
