# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.fraude_preproceser import FraudPreprocessPipeline

df = pd.read_csv("../data/processed/fraud_features.csv")

pipeline = FraudPreprocessPipeline(
    df, 
    target="class", 
    output_path="../data/processed/fraud_balanced_data.csv"
)
result = pipeline.run()

result["before"]  # class distribution before balancing
result["after"]   # class distribution after SMOTE
# Out:
# class
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from scripts.fraude_preproceser import FraudPreprocessPipeline
df = pd.read_csv("../data/processed/credit_clean.csv")

pipeline = FraudPreprocessPipeline(
    df, 
    target="Class", 
    output_path="../data/processed/credit_balanced_data.csv"
)
result = pipeline.run()

result["before"]
result["after"]
# Out:
# Class
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
